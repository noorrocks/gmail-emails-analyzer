# %% [markdown]
# # Python Programming - Projects
#
# ## Project 2
#
#
# Objective: The objective of this project is to analyze the email data you collected in the previous project.

# %% [markdown]
# ### Function Definitions

# %%
## All imports

import os
import re
import csv

# %%
def context_separator(sep_char='^', ln=50):
    return( sep_char*ln )

# %%
import sys, traceback

def print_trace():
    exc_type, exc_value, exc_traceback = sys.exc_info()

    print("*** print_tb:")
    traceback.print_tb(exc_traceback, limit=1, file=sys.stdout)
    
    print( "\n*** print_exception:\n")
    traceback.print_exception(exc_type, exc_value, exc_traceback,
                              limit=2, file=sys.stdout)
    print ("\n*** print_exc:\n")
    traceback.print_exc()
    
    print( "\n*** format_exc, first and last line:\n")
    formatted_lines = traceback.format_exc().splitlines()
    print (formatted_lines[0])
    print (formatted_lines[-1])
    
    print ("\n*** format_exception:\n")
    print (repr(traceback.format_exception(exc_type, exc_value,
                                          exc_traceback)))
    print ("\n*** extract_tb:\n")
    print (repr(traceback.extract_tb(exc_traceback)))
    
    print ("\n*** format_tb:\n")
    print (repr(traceback.format_tb(exc_traceback)))
    
    print ("\n*** tb_lineno:", exc_traceback.tb_lineno)

# %%
# Pattern matching in single email and extraction of string
import codecs

def getemailbypat(filepath, field='to', pattern='.*'):
    
    
    try:        
#         fhandle = open(filepath)

        with codecs.open(filepath, "r", encoding='utf-8', errors='ignore') as fhandle:
        
            eml = fhandle.read()

            field = field.capitalize()

            if field == 'Body':
                field_patt = '\nContent-Type:[\s\S]*$'
            else:
                field_patt = '\n'+field+':.*?\n'

            field_ext = re.findall(field_patt, eml)
            field_ext_str = field_ext[0]
            pattern_ext = re.findall(pattern, field_ext_str)

            return pattern_ext

        
    except:
        
        print( context_separator())
        print( "function name= ", "\'getmemailbypat\'")
        print(context_separator())
        print_trace()
        
        print("\n**** Context Information ***\n")
        
        print( "function name= ", "\'getmemailbypat\'")
        print( "filepath= ", filepath )
        print( "field= ", field)
        print( "pattern= ", pattern)
        
        try: 
            eml 
        except: 
            eml = None
        
        print( "eml= ", eml if eml is not None else "emal_not_defined")
        
        
        print( context_separator())

# %%
# traversing through the folder structures to get the file name and calling getmeialbypat for each file

def create_gmaildata_csv(path):

    try:

        date_regex_pat = 'Date: ([A-Z][a-z]+.*)'
        email_regex_pat = '<(\S+@\S+)>'

        with open('./gmail_data.csv', "w", newline='') as csv_file:
            writer = csv.writer(csv_file, delimiter=',')
            
            # write header
            line = ( "FolderName,FileName,DateReceived,FromEmail,ToEmail".split(",") )
            
            # Write data to a CSV file path
            writer.writerow(line)

            for root, dirs, files in os.walk(path):            
                for file_ in files:                
                    if file_.endswith(".eml"):

                        filepath =  os.path.join(root, file_) 
                             
                        date_extract = getemailbypat( filepath, 'date', date_regex_pat )
                        from_extract = getemailbypat( filepath, 'to', email_regex_pat )
                        to_extract   = getemailbypat( filepath, 'from', email_regex_pat )

                        line = ( root, file_, ''.join(date_extract), ''.join(from_extract), ''.join(to_extract) )
                        
                        # Write data to a CSV file path
                        writer.writerow(line)

#                         print( 'No: {}; File: {}; Pattern Match: {}'.format(counter, filepath, extract_string))
                          
                    
    except:
#                
        
        print( context_separator())
        print( "function name= ", "\'getmemailbypat\'")
        print(context_separator())
        print_trace()
        
        print("\n**** Context Information ***\n")
        
        print( "function name= ", "\'getmemailbypat\'")
        print( "filepath= ", filepath )
        print( "field= ", field)
        print( "pattern= ", pattern)
        
        try: 
            eml 
        except: 
            eml = None
        
        print( "eml= ", eml if eml is not None else "emal_not_defined")
        
        
        print( context_separator())

# %%
# Calling of gmail_data_csv function 

create_gmaildata_csv('/home/noorrocks1796/got-your-back/GYB-GMail-Backup-noorrocks@gmail.com/')
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# function name=  'getmemailbypat'
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# *** print_tb:
#   File "<ipython-input-100-4d51f54f2a98>", line 22, in getemailbypat
#     field_ext_str = field_ext[0]
#
# *** print_exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-100-4d51f54f2a98>", line 22, in getemailbypat
#     field_ext_str = field_ext[0]
# IndexError: list index out of range
#
# *** print_exc:
#
#
# *** format_exc, first and last line:
#
# Traceback (most recent call last):
# IndexError: list index out of range
#
# *** format_exception:
#
# ['Traceback (most recent call last):\n', '  File "<ipython-input-100-4d51f54f2a98>", line 22, in getemailbypat\n    field_ext_str = field_ext[0]\n', 'IndexError: list index out of range\n']
#
# *** extract_tb:
#
# [<FrameSummary file <ipython-input-100-4d51f54f2a98>, line 22 in getemailbypat>]
#
# *** format_tb:
#
# ['  File "<ipython-input-100-4d51f54f2a98>", line 22, in getemailbypat\n    field_ext_str = field_ext[0]\n']
#
# *** tb_lineno: 22
#
# **** Context Information ***
#
# function name=  'getmemailbypat'
# filepath=  /home/noorrocks1796/got-your-back/GYB-GMail-Backup-noorrocks@gmail.com/2011/8/11/131b773b51e51955.eml
# field=  To
# pattern=  <(\S+@\S+)>
# eml=  Delivered-To: noorrocks@gmail.com
# Received: by 10.231.36.65 with SMTP id s1cs226612ibd;
#         Wed, 10 Aug 2011 23:07:25 -0700 (PDT)
# Return-Path: <toronto-friendscircle+bncCAAQluON8gQaBKS0Hnw@googlegroups.com>
# Received-SPF: pass (google.com: domain of toronto-friendscircle+bncCAAQluON8gQaBKS0Hnw@googlegroups.com designates 10.220.108.196 as permitted sender) client-ip=10.220.108.196;
# Authentication-Results: mr.google.com; spf=pass (google.com: domain of toronto-friendscircle+bncCAAQluON8gQaBKS0Hnw@googlegroups.com designates 10.220.108.196 as permitted sender) smtp.mail=toronto-friendscircle+bncCAAQluON8gQaBKS0Hnw@googlegroups.com; dkim=pass header.i=toronto-friendscircle+bncCAAQluON8gQaBKS0Hnw@googlegroups.com
# Received: from mr.google.com ([10.220.108.196])
#         by 10.220.108.196 with SMTP id g4mr328341vcp.49.1313042844483 (num_hops = 1);
#         Wed, 10 Aug 2011 23:07:24 -0700 (PDT)
# DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;
#         d=googlegroups.com; s=beta;
#         h=x-beenthere:received-spf:message-id:x-originating-ip:from:subject
#          :date:importance:mime-version:x-originalarrivaltime
#          :x-original-sender:x-original-authentication-results:reply-to
#          :precedence:mailing-list:list-id:x-google-group-id:list-post
#          :list-help:list-archive:sender:list-unsubscribe:content-type;
#         bh=NftXU9Z9Jyu8b+pIEzFSsRx26IOVN+EINWV+efOtbG8=;
#         b=n/8Y7aeC2I1MSk0+nC2KDqzQRjM+f5ZM4jKuniOttRZTON2s4kupApsC3h0vqlricn
#          mSpE1GJUc8vrUUNtLf0HTo5DreMJIzlwyAgrLePTD8w8Krvtm22YDBcz5GJrERIjd9WA
#          WGUsyuuHyEKVFmL1JtSaNIvV9f4bSSV5/Kv6Y=
# Received: by 10.220.108.196 with SMTP id g4mr98882vcp.49.1313042838652;
#         Wed, 10 Aug 2011 23:07:18 -0700 (PDT)
# X-BeenThere: toronto-friendscircle@googlegroups.com
# Received: by 10.52.161.199 with SMTP id xu7ls1540239vdb.0.gmail; Wed, 10 Aug
#  2011 23:07:18 -0700 (PDT)
# Received: by 10.52.91.134 with SMTP id ce6mr593924vdb.13.1313042838143;
#         Wed, 10 Aug 2011 23:07:18 -0700 (PDT)
# Received: by 10.52.91.134 with SMTP id ce6mr593923vdb.13.1313042838132;
#         Wed, 10 Aug 2011 23:07:18 -0700 (PDT)
# Received: from snt0-omc4-s17.snt0.hotmail.com (snt0-omc4-s17.snt0.hotmail.com [65.55.90.220])
#         by gmr-mx.google.com with ESMTP id bh5si2209095vdc.3.2011.08.10.23.07.17;
#         Wed, 10 Aug 2011 23:07:18 -0700 (PDT)
# Received-SPF: pass (google.com: domain of roshankhan504@hotmail.com designates 65.55.90.220 as permitted sender) client-ip=65.55.90.220;
# Received: from SNT141-W53 ([65.55.90.201]) by snt0-omc4-s17.snt0.hotmail.com with Microsoft SMTPSVC(6.0.3790.4675);
# 	 Wed, 10 Aug 2011 23:07:17 -0700
# Message-ID: <SNT141-W530AB6430382098B896A70FB220@phx.gbl>
# X-Originating-IP: [123.11.167.106]
# From: roshan khan <roshankhan504@hotmail.com>
# Subject:
# Date: Thu, 11 Aug 2011 10:07:17 +0400
# Importance: Normal
# MIME-Version: 1.0
# Bcc:
# X-OriginalArrivalTime: 11 Aug 2011 06:07:17.0744 (UTC) FILETIME=[EC6E1F00:01CC57EC]
# X-Original-Sender: roshankhan504@hotmail.com
# X-Original-Authentication-Results: gmr-mx.google.com; spf=pass (google.com:
#  domain of roshankhan504@hotmail.com designates 65.55.90.220 as permitted
#  sender) smtp.mail=roshankhan504@hotmail.com
# Reply-To: toronto-friendscircle@googlegroups.com
# Precedence: list
# Mailing-list: list toronto-friendscircle@googlegroups.com; contact toronto-friendscircle+owners@googlegroups.com
# List-ID: <toronto-friendscircle.googlegroups.com>
# X-Google-Group-Id: 840723952517
# List-Post: <http://groups.google.com/group/Toronto-FriendsCircle/post?hl=en_US>,
#  <mailto:Toronto-FriendsCircle@googlegroups.com>
# List-Help: <http://groups.google.com/support/?hl=en_US>, <mailto:Toronto-FriendsCircle+help@googlegroups.com>
# List-Archive: <http://groups.google.com/group/Toronto-FriendsCircle?hl=en_US>
# Sender: toronto-friendscircle@googlegroups.com
# List-Unsubscribe: <http://groups.google.com/group/Toronto-FriendsCircle/subscribe?hl=en_US>,
#  <mailto:Toronto-FriendsCircle+unsubscribe@googlegroups.com>
# Content-Type: multipart/alternative;
# 	boundary="_7149218d-dda9-4c52-a7e4-78f32ed0dd9c_"
#
# --_7149218d-dda9-4c52-a7e4-78f32ed0dd9c_
# Content-Type: text/plain; charset=UTF-8
# Content-Transfer-Encoding: quoted-printable
#
#
# BettyHey=EF=BC=8Cgood news!
#      I ordered one black Apple5 (32GB) (64GB) from this website www.happy-g=
# obuying.com
#        one weeks ago, today I've got it .  Amazing,beyond my imagination, i=
# t's genuine
# and as good as expected,but much cheaper. I'm pleased to share this good ne=
# ws  with you!
# May all goes well for you.=20
#  Happy every.  		 	   		 =20
#
# --=20
# [Let's Network for a Common Cause & the Social Growth of this Fraternity!]
# --
# You received this message because you are subscribed to the Google
# Groups "Toronto-FriendsCircle" group.
# To post to this group, send email to
# Toronto-FriendsCircle@googlegroups.com
# To unsubscribe from this group, send email to
# Toronto-FriendsCircle+unsubscribe@googlegroups.com
# For more options, visit this group at
# http://groups.google.com/group/Toronto-FriendsCircle?hl=3Den?hl=3Den
#
# --_7149218d-dda9-4c52-a7e4-78f32ed0dd9c_
# Content-Type: text/html; charset=UTF-8
# Content-Transfer-Encoding: quoted-printable
#
# <html>
# <head>
# <style><!--
# .hmmessage P
# {
# margin:0px;
# padding:0px
# }
# body.hmmessage
# {
# font-size: 10pt;
# font-family:Tahoma
# }
# --></style>
# </head>
# <body class=3D'hmmessage'><div dir=3D'ltr'>
# Betty<STRONG>Hey=EF=BC=8Cgood news!<BR>&nbsp;&nbsp; &nbsp; I ordered one bl=
# ack Apple5 (32GB) (64GB) from this website </STRONG><A href=3D"http://www.h=
# appy-gobuying.com/" target=3D_blank><FONT color=3D#0000ff><STRONG>www.happy=
# -gobuying.com</STRONG></FONT></A><A href=3D"http://www.ove-buy.com/" target=
# =3D_blank></A><BR><FONT color=3D#993300><FONT color=3D#000000><STRONG>&nbsp=
# ;&nbsp; &nbsp; &nbsp; one weeks ago, today I've got it .&nbsp; Amazing,beyo=
# nd my imagination, it's genuine<BR>and as good as expected,but much cheaper=
# . I'm pleased to share this good news&nbsp; with you!<BR>May all goes well =
# for you.</STRONG></FONT> </FONT>
# <DIV>&nbsp;</DIV>Happy every.  		 	   		  </div></body>
# </html>
#
# <p></p>
#
# -- <br />
# [Let&#39;s Network for a Common Cause &amp; the Social Growth of this Frate=
# rnity!]<br />
# --<br />
# You received this message because you are subscribed to the Google<br />
# Groups &quot;Toronto-FriendsCircle&quot; group.<br />
# To post to this group, send email to<br />
# Toronto-FriendsCircle@googlegroups.com<br />
# To unsubscribe from this group, send email to<br />
# Toronto-FriendsCircle+unsubscribe@googlegroups.com<br />
# For more options, visit this group at<br />
# <a href=3D"http://groups.google.com/group/Toronto-FriendsCircle?hl=3Den?hl=
# =3Den">http://groups.google.com/group/Toronto-FriendsCircle?hl=3Den?hl=3Den=
# </a><br />
#
# --_7149218d-dda9-4c52-a7e4-78f32ed0dd9c_--
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# function name=  'getmemailbypat'
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# *** print_tb:
#   File "<ipython-input-103-21bb6b9c3c76>", line 29, in create_gmaildata_csv
#     line = ( root, file_, ''.join(date_extract), ''.join(from_extract), ''.join(to_extract) )
#
# *** print_exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-103-21bb6b9c3c76>", line 29, in create_gmaildata_csv
#     line = ( root, file_, ''.join(date_extract), ''.join(from_extract), ''.join(to_extract) )
# TypeError: can only join an iterable
#
# *** print_exc:
#
#
# *** format_exc, first and last line:
#
# Traceback (most recent call last):
# TypeError: can only join an iterable
#
# *** format_exception:
#
# ['Traceback (most recent call last):\n', '  File "<ipython-input-103-21bb6b9c3c76>", line 29, in create_gmaildata_csv\n    line = ( root, file_, \'\'.join(date_extract), \'\'.join(from_extract), \'\'.join(to_extract) )\n', 'TypeError: can only join an iterable\n']
#
# *** extract_tb:
#
# [<FrameSummary file <ipython-input-103-21bb6b9c3c76>, line 29 in create_gmaildata_csv>]
#
# *** format_tb:
#
# ['  File "<ipython-input-103-21bb6b9c3c76>", line 29, in create_gmaildata_csv\n    line = ( root, file_, \'\'.join(date_extract), \'\'.join(from_extract), \'\'.join(to_extract) )\n']
#
# *** tb_lineno: 29
#
# **** Context Information ***
#
# function name=  'getmemailbypat'
# filepath=  /home/noorrocks1796/got-your-back/GYB-GMail-Backup-noorrocks@gmail.com/2011/8/11/131b773b51e51955.eml
# field=  To
# Traceback (most recent call last):
#   File "<ipython-input-100-4d51f54f2a98>", line 22, in getemailbypat
#     field_ext_str = field_ext[0]
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-103-21bb6b9c3c76>", line 29, in create_gmaildata_csv
#     line = ( root, file_, ''.join(date_extract), ''.join(from_extract), ''.join(to_extract) )
# TypeError: can only join an iterable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-21bb6b9c3c76> in create_gmaildata_csv(path)
#      28
# ---> 29                         line = ( root, file_, ''.join(date_extract), ''.join(from_extract), ''.join(to_extract) )
#      30
#
# TypeError: can only join an iterable
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-444ec0a26097> in <module>()
#       1 # Calling of gmail_data_csv function
#       2
# ----> 3 create_gmaildata_csv('/home/noorrocks1796/got-your-back/GYB-GMail-Backup-noorrocks@gmail.com/')
#
# <ipython-input-103-21bb6b9c3c76> in create_gmaildata_csv(path)
#      48         print( "filepath= ", filepath )
#      49         print( "field= ", field)
# ---> 50         print( "pattern= ", pattern)
#      51
#      52         try:
#
# NameError: name 'pattern' is not defined

# %%
line = ( "Filename,DateReceived,From,To".split(",") )
print(line)
# Out:
# ['Filename', 'DateReceived', 'From', 'To']

# %%
import sys, traceback

def print_trace():
    exc_type, exc_value, exc_traceback = sys.exc_info()
    
    print ("*** print_tb:")
    traceback.print_tb(exc_traceback, limit=1, file=sys.stdout)
    
    print( "\n*** print_exception:\n")
    traceback.print_exception(exc_type, exc_value, exc_traceback,
                              limit=2, file=sys.stdout)
    print ("\n*** print_exc:\n")
    traceback.print_exc()
    
    print( "\n*** format_exc, first and last line:\n")
    formatted_lines = traceback.format_exc().splitlines()
    print (formatted_lines[0])
    print (formatted_lines[-1])
    
    print ("\n*** format_exception:\n")
    print (repr(traceback.format_exception(exc_type, exc_value,
                                          exc_traceback)))
    print ("\n*** extract_tb:\n")
    print (repr(traceback.extract_tb(exc_traceback)))
    
    print ("\n*** format_tb:\n")
    print (repr(traceback.format_tb(exc_traceback)))
    
    print ("\n*** tb_lineno:", exc_traceback.tb_lineno)
# Out:
# *** print_tb:
#   File "<ipython-input-52-7536b33aac00>", line 11, in <module>
#     lumberjack()
#
# *** print_exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-52-7536b33aac00>", line 11, in <module>
#     lumberjack()
#   File "<ipython-input-52-7536b33aac00>", line 4, in lumberjack
#     bright_side_of_death()
# IndexError: tuple index out of range
#
# *** print_exc:
#
#
# *** format_exc, first and last line:
#
# Traceback (most recent call last):
# IndexError: tuple index out of range
#
# *** format_exception:
#
# ['Traceback (most recent call last):\n', '  File "<ipython-input-52-7536b33aac00>", line 11, in <module>\n    lumberjack()\n', '  File "<ipython-input-52-7536b33aac00>", line 4, in lumberjack\n    bright_side_of_death()\n', '  File "<ipython-input-52-7536b33aac00>", line 7, in bright_side_of_death\n    return tuple()[0]\n', 'IndexError: tuple index out of range\n']
#
# *** extract_tb:
#
# [<FrameSummary file <ipython-input-52-7536b33aac00>, line 11 in <module>>, <FrameSummary file <ipython-input-52-7536b33aac00>, line 4 in lumberjack>, <FrameSummary file <ipython-input-52-7536b33aac00>, line 7 in bright_side_of_death>]
#
# *** format_tb:
#
# ['  File "<ipython-input-52-7536b33aac00>", line 11, in <module>\n    lumberjack()\n', '  File "<ipython-input-52-7536b33aac00>", line 4, in lumberjack\n    bright_side_of_death()\n', '  File "<ipython-input-52-7536b33aac00>", line 7, in bright_side_of_death\n    return tuple()[0]\n']
#
# *** tb_lineno: 11
# Traceback (most recent call last):
#   File "<ipython-input-52-7536b33aac00>", line 11, in <module>
#     lumberjack()
#   File "<ipython-input-52-7536b33aac00>", line 4, in lumberjack
#     bright_side_of_death()
#   File "<ipython-input-52-7536b33aac00>", line 7, in bright_side_of_death
#     return tuple()[0]
# IndexError: tuple index out of range

# %%
help(open)
# Out:
# Help on built-in function open in module io:
#
# open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)
#     Open file and return a stream.  Raise IOError upon failure.
#
#     file is either a text or byte string giving the name (and the path
#     if the file isn't in the current working directory) of the file to
#     be opened or an integer file descriptor of the file to be
#     wrapped. (If a file descriptor is given, it is closed when the
#     returned I/O object is closed, unless closefd is set to False.)
#
#     mode is an optional string that specifies the mode in which the file
#     is opened. It defaults to 'r' which means open for reading in text
#     mode.  Other common values are 'w' for writing (truncating the file if
#     it already exists), 'x' for creating and writing to a new file, and
#     'a' for appending (which on some Unix systems, means that all writes
#     append to the end of the file regardless of the current seek position).
#     In text mode, if encoding is not specified the encoding used is platform
#     dependent: locale.getpreferredencoding(False) is called to get the
#     current locale encoding. (For reading and writing raw bytes use binary
#     mode and leave encoding unspecified.) The available modes are:
#
#     ========= ===============================================================
#     Character Meaning
#     --------- ---------------------------------------------------------------
#     'r'       open for reading (default)
#     'w'       open for writing, truncating the file first
#     'x'       create a new file and open it for writing
#     'a'       open for writing, appending to the end of the file if it exists
#     'b'       binary mode
#     't'       text mode (default)
#     '+'       open a disk file for updating (reading and writing)
#     'U'       universal newline mode (deprecated)
#     ========= ===============================================================
#
#     The default mode is 'rt' (open for reading text). For binary random
#     access, the mode 'w+b' opens and truncates the file to 0 bytes, while
#     'r+b' opens the file without truncation. The 'x' mode implies 'w' and
#     raises an `FileExistsError` if the file already exists.
#
#     Python distinguishes between files opened in binary and text modes,
#     even when the underlying operating system doesn't. Files opened in
#     binary mode (appending 'b' to the mode argument) return contents as
#     bytes objects without any decoding. In text mode (the default, or when
#     't' is appended to the mode argument), the contents of the file are
#     returned as strings, the bytes having been first decoded using a
#     platform-dependent encoding or using the specified encoding if given.
#
#     'U' mode is deprecated and will raise an exception in future versions
#     of Python.  It has no effect in Python 3.  Use newline to control
#     universal newlines mode.
#
#     buffering is an optional integer used to set the buffering policy.
#     Pass 0 to switch buffering off (only allowed in binary mode), 1 to select
#     line buffering (only usable in text mode), and an integer > 1 to indicate
#     the size of a fixed-size chunk buffer.  When no buffering argument is
#     given, the default buffering policy works as follows:
#
#     * Binary files are buffered in fixed-size chunks; the size of the buffer
#       is chosen using a heuristic trying to determine the underlying device's
#       "block size" and falling back on `io.DEFAULT_BUFFER_SIZE`.
#       On many systems, the buffer will typically be 4096 or 8192 bytes long.
#
#     * "Interactive" text files (files for which isatty() returns True)
#       use line buffering.  Other text files use the policy described above
#       for binary files.
#
#     encoding is the name of the encoding used to decode or encode the
#     file. This should only be used in text mode. The default encoding is
#     platform dependent, but any encoding supported by Python can be
#     passed.  See the codecs module for the list of supported encodings.
#
#     errors is an optional string that specifies how encoding errors are to
#     be handled---this argument should not be used in binary mode. Pass
#     'strict' to raise a ValueError exception if there is an encoding error
#     (the default of None has the same effect), or pass 'ignore' to ignore
#     errors. (Note that ignoring encoding errors can lead to data loss.)
#     See the documentation for codecs.register or run 'help(codecs.Codec)'
#     for a list of the permitted encoding error strings.
#
#     newline controls how universal newlines works (it only applies to text
#     mode). It can be None, '', '\n', '\r', and '\r\n'.  It works as
#     follows:
#
#     * On input, if newline is None, universal newlines mode is
#       enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#       these are translated into '\n' before being returned to the
#       caller. If it is '', universal newline mode is enabled, but line
#       endings are returned to the caller untranslated. If it has any of
#       the other legal values, input lines are only terminated by the given
#       string, and the line ending is returned to the caller untranslated.
#
#     * On output, if newline is None, any '\n' characters written are
#       translated to the system default line separator, os.linesep. If
#       newline is '' or '\n', no translation takes place. If newline is any
#       of the other legal values, any '\n' characters written are translated
#       to the given string.
#
#     If closefd is False, the underlying file descriptor will be kept open
#     when the file is closed. This does not work when a file name is given
#     and must be True in that case.
#
#     A custom opener can be used by passing a callable as *opener*. The
#     underlying file descriptor for the file object is then obtained by
#     calling *opener* with (*file*, *flags*). *opener* must return an open
#     file descriptor (passing os.open as *opener* results in functionality
#     similar to passing None).
#
#     open() returns a file object whose type depends on the mode, and
#     through which the standard file operations such as reading and writing
#     are performed. When open() is used to open a file in a text mode ('w',
#     'r', 'wt', 'rt', etc.), it returns a TextIOWrapper. When used to open
#     a file in a binary mode, the returned class varies: in read binary
#     mode, it returns a BufferedReader; in write binary and append binary
#     modes, it returns a BufferedWriter, and in read/write mode, it returns
#     a BufferedRandom.
#
#     It is also possible to use a string or bytearray as a file for both
#     reading and writing. For strings StringIO can be used like a file
#     opened in a text mode, and for bytes a BytesIO can be used like a file
#     opened in a binary mode.
